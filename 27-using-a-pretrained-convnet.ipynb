# %% [markdown]
# <img src="http://akhavanpour.ir/notebook/images/srttu.gif" alt="SRTTU" style="width: 150px;"/>
#
# [![Azure Notebooks](https://notebooks.azure.com/launch.png)](https://notebooks.azure.com/import/gh/Alireza-Akhavan/class.vision)

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">استفاده از شبکه‌های از قبل آموزش داده شده</div>

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# خطای رایج:
# <br>
# [cannot download vgg16_weights](https://github.com/fchollet/deep-learning-models/issues/33)
# <br>
# راهکار؟
# <br>
# </div>
# You can download it manually from here: https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# and paste it on
# ~/.keras/models

# %%
import os
os.path.expanduser('~/.keras/models')
# Out:
# 'C:\\Users\\A s u s/.keras/models'

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = VGG16(weights='imagenet')

# %%
img_path = './images/elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02504458', 'African_elephant', 0.75295341), ('n01871265', 'tusker', 0.2060758), ('n02504013', 'Indian_elephant', 0.040970467)]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> دانشگاه تربیت دبیر شهید رجایی<br>مباحث ویژه - آشنایی با بینایی کامپیوتر<br>علیرضا اخوان پور<br>96-97<br>
# </div>
# <a href="https://www.srttu.edu/">SRTTU.edu</a> - <a href="http://class.vision">Class.Vision</a> - <a href="http://AkhavanPour.ir">AkhavanPour.ir</a>
# </div>
